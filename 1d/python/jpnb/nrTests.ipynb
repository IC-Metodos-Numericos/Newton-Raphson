# %%
from nrdef import runNRM
# Out:
# c:\Users\lumat\anaconda3\Lib\site-packages\kaleido\__init__.py:14: UserWarning:
#
# ...
#
# This means that static image generation (e.g. `fig.write_image()`) will not work.
#
# Please upgrade Plotly to version 6.1.1 or greater, or downgrade Kaleido to version 0.2.1.
#
#   from .kaleido import Kaleido

# %%
runNRM()
# Out:
# Método de Newton-Raphson
# Função: x + cos(x),
#  Derivada: 1 - sin(x),
#  Ponto Inicial (x0): 1.0
# Quantidade De Iterações: 9, Raiz: -0.7391
# Iteração 1: x = 1.00000000000000000, f(x) = 1.54030230586813977
# Iteração 2: x = -8.71621695877956881, f(x) = -9.47551603677020893
# Iteração 3: x = -2.97606065509691220, f(x) = -3.96239148886560244
# Iteração 4: x = 0.42578468868523034, f(x) = 1.33649959774053784
# Iteração 5: x = -1.85118381773117902, f(x) = -2.12791184581029080
# Iteração 6: x = -0.76603951964493078, f(x) = -0.04537745765676393
# Iteração 7: x = -0.73924106749608209, f(x) = -0.00026098247349871
# Iteração 8: x = -0.73908513858327585, f(x) = -0.00000000898414221
# Iteração 9: x = -0.73908513321516067, f(x) = 0.00000000000000000
# (-0.7390851332151607,
#  [1.0,
#   -8.716216958779569,
#   -2.976060655096912,
#   0.42578468868523034,
#   -1.851183817731179,
#   -0.7660395196449308,
#   -0.7392410674960821,
#   -0.7390851385832758,
#   -0.7390851332151607])

# %%
x + cosx
