# %%
from nrdef import runNRM
# Out:
# C:\Users\maria\AppData\Roaming\Python\Python313\site-packages\kaleido\__init__.py:14: UserWarning:
#
# ...
#
# This means that static image generation (e.g. `fig.write_image()`) will not work.
#
# Please upgrade Plotly to version 6.1.1 or greater, or downgrade Kaleido to version 0.2.1.
#
#   from .kaleido import Kaleido

# %%
runNRM()
# Out:
# Método de Newton-Raphson
# Função: 3*x,
#  Derivada: 3,
#  Ponto Inicial (x0): 2.0
# Quantidade De Iterações: 3, Raiz: 0.0000
# Iteração 1: x = 2.00000000000000000, f(x) = 6.00000000000000000
# Iteração 2: x = 0.00000000000000000, f(x) = 0.00000000000000000
# Iteração 3: x = 0.00000000000000000, f(x) = 0.00000000000000000
# (0.0, [2.0, 0.0, 0.0])
