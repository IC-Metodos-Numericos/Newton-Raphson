# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-2, 2, 1000)
y = (x**3) + 5*(x**5) - 7*(x**7)

plt.plot(x, y)
plt.grid(True)
plt.title("f(x) = x³ + 5x⁵ - 7x⁷")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.show()
