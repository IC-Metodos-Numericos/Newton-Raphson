# %%
from nrDef import runNRM
# Out:
# C:\Users\maria\AppData\Roaming\Python\Python313\site-packages\kaleido\__init__.py:14: UserWarning:
#
# ...
#
# This means that static image generation (e.g. `fig.write_image()`) will not work.
#
# Please upgrade Plotly to version 6.1.1 or greater, or downgrade Kaleido to version 0.2.1.
#
#   from .kaleido import Kaleido

# %%
f = "x**2 - 2"
x0 = 0.5

# %%
runNRM(f, x0, 0)
# Out:
# Método de Newton-Raphson
# Função: x**2 - 2,
#  Derivada: 2*x,
#  Ponto Inicial (x0): 0.5
# Quantidade De Iterações: 7, Raiz: 1.4142
# Iteração 1: x = 0.50000000000000000, f(x) = -1.75000000000000000
# Iteração 2: x = 2.25000000000000000, f(x) = 3.06250000000000000
# Iteração 3: x = 1.56944444444444442, f(x) = 0.46315586419753085
# Iteração 4: x = 1.42189036381514256, f(x) = 0.02177220671035851
# Iteração 5: x = 1.41423428594007339, f(x) = 0.00005861552842923
# Iteração 6: x = 1.41421356252493213, f(x) = 0.00000000042946002
# Iteração 7: x = 1.41421356237309515, f(x) = 0.00000000000000044
#
# Erros Absolutos:
# Iteração 1: Erro = 0.50000000000000000
# Iteração 2: Erro = 2.25000000000000000
# Iteração 3: Erro = 1.56944444444444442
# Iteração 4: Erro = 1.42189036381514256
# Iteração 5: Erro = 1.41423428594007339
# Iteração 6: Erro = 1.41421356252493213
# Iteração 7: Erro = 1.41421356237309515
# (1.4142135623730951,
#  [0.5,
#   2.25,
#   1.5694444444444444,
#   1.4218903638151426,
# ...
