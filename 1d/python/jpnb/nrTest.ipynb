# %%
from nrDef import runNRM
# Out:
# C:\Users\maria\AppData\Roaming\Python\Python313\site-packages\kaleido\__init__.py:14: UserWarning:
#
# ...
#
# This means that static image generation (e.g. `fig.write_image()`) will not work.
#
# Please upgrade Plotly to version 6.1.1 or greater, or downgrade Kaleido to version 0.2.1.
#
#   from .kaleido import Kaleido

# %%
f = "sin(x) - x/2"
x0 = 0.5

# %%
runNRM(f, x0)
# Out:
# Método de Newton-Raphson
# Função: -x/2 + sin(x),
#  Derivada: cos(x) - 1/2,
#  Ponto Inicial (x0): 0.5
# Quantidade De Iterações: 5, Raiz: 0.0000
# Iteração 1: x = 0.50000000000000000, f(x) = 0.22942553860420301
# Iteração 2: x = -0.10761688107517631, f(x) = -0.05360083522481292
# Iteração 3: x = 0.00083965536339252, f(x) = 0.00041982758303380
# Iteração 4: x = -0.00000000039465010, f(x) = -0.00000000019732505
# Iteração 5: x = 0.00000000000000000, f(x) = 0.00000000000000000
# (np.float64(0.0),
#  [0.5,
#   np.float64(-0.10761688107517631),
#   np.float64(0.0008396553633925191),
#   np.float64(-3.946500987334414e-10),
#   np.float64(0.0)])
