# %%
from nrDef import runNRM
# Out:
# C:\Users\maria\AppData\Roaming\Python\Python313\site-packages\kaleido\__init__.py:14: UserWarning:
#
# ...
#
# This means that static image generation (e.g. `fig.write_image()`) will not work.
#
# Please upgrade Plotly to version 6.1.1 or greater, or downgrade Kaleido to version 0.2.1.
#
#   from .kaleido import Kaleido

# %%
runNRM(
    f = "x**10 - 1",
    x0 = 0.5,
    know_root=1,  # Known root for the function x^3 - 2x - 5
    tol=1e-6,
    max_iter=100
    )
# Out:
# Método de Newton-Raphson
# Função: x**10 - 1,
#  Derivada: 10*x**9,
#  Ponto Inicial (x0): 0.5
# ✓ Convergiu! Quantidade De Iterações: 43, Raiz: 1.0000
# Iteração 1: x = 0.50000000000000000, f(x) = -0.99902343750000000
# Iteração 2: x = 51.64999999999999858, f(x) = 135114904483913696.00000000000000000
# Iteração 3: x = 46.48499999999999943, f(x) = 47111654129711536.00000000000000000
# Iteração 4: x = 41.83650000000000091, f(x) = 16426818072478544.00000000000000000
# Iteração 5: x = 37.65285000000000082, f(x) = 5727677301318307.00000000000000000
# Iteração 6: x = 33.88756500000000216, f(x) = 1997117586819845.25000000000000000
# Iteração 7: x = 30.49880850000000265, f(x) = 696351844868619.50000000000000000
# Iteração 8: x = 27.44892765000000878, f(x) = 242802875029547.34375000000000000
# Iteração 9: x = 24.70403488500001998, f(x) = 84660127717097.56250000000000000
# Iteração 10: x = 22.23363139650004783, f(x) = 29519161271064.09765625000000000
# ...
