# %%
from nrDef import runNRM

# %%
runNRM(f, x0)
# Out:
# Método de Newton-Raphson
# Função: -x + cos(x),
#  Derivada: -sin(x) - 1,
#  Ponto Inicial (x0): 0.5
# Quantidade De Iterações: 5, Raiz: 0.7391
# Iteração 1: x = 0.50000000000000000, f(x) = 0.37758256189037276
# Iteração 2: x = 0.75522241710563642, f(x) = -0.02710331185746728
# Iteração 3: x = 0.73914166614987920, f(x) = -0.00009461538061772
# Iteração 4: x = 0.73908513392080677, f(x) = -0.00000000118097787
# Iteração 5: x = 0.73908513321516067, f(x) = 0.00000000000000000
# (np.float64(0.7390851332151607),
#  [0.5,
#   np.float64(0.7552224171056364),
#   np.float64(0.7391416661498792),
#   np.float64(0.7390851339208068),
#   np.float64(0.7390851332151607)])
