# %%
from nrDef import runNRM
# Out:
# C:\Users\maria\AppData\Roaming\Python\Python313\site-packages\kaleido\__init__.py:14: UserWarning:
#
# ...
#
# This means that static image generation (e.g. `fig.write_image()`) will not work.
#
# Please upgrade Plotly to version 6.1.1 or greater, or downgrade Kaleido to version 0.2.1.
#
#   from .kaleido import Kaleido

# %%
runNRM(
    f="x* (cos(2*x)) * 0.01",
    x0=4.75,
    know_root=None,
    tol=1e-6,
    max_iter=100
)
# Out:
# Método de Newton-Raphson
# Função: 0.01*x*cos(2*x),
#  Derivada: -0.02*x*sin(2*x) + 0.01*cos(2*x),
#  Ponto Inicial (x0): 4.75
# ✓ Convergiu! Quantidade De Iterações: 5, Raiz: -11.7810
# Iteração 1: x = 4.75000000000000000, f(x) = -0.04736567741932798
# Iteração 2: x = -11.97301255116330410, f(x) = -0.04486365737362013
# Iteração 3: x = -11.77429070649470333, f(x) = 0.00157340920400228
# Iteração 4: x = -11.78097664313937010, f(x) = -0.00000098775893849
# Iteração 5: x = -11.78097245096321544, f(x) = -0.00000000000035126
# Iteração 6: x = -11.78097245096172507, f(x) = -0.00000000000000010
# {'root': np.float64(-11.780972450961725),
#  'iterations': [4.75,
#   np.float64(-11.973012551163304),
#   np.float64(-11.774290706494703),
#   np.float64(-11.78097664313937),
#   np.float64(-11.780972450963215),
#   np.float64(-11.780972450961725)],
#  'converged': True,
#  'error_message': None,
#  'final_iteration': 5}
