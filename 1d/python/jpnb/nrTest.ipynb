# %%
from nrDef import runNRM
# Out:
# C:\Users\maria\AppData\Roaming\Python\Python313\site-packages\kaleido\__init__.py:14: UserWarning:
#
# ...
#
# This means that static image generation (e.g. `fig.write_image()`) will not work.
#
# Please upgrade Plotly to version 6.1.1 or greater, or downgrade Kaleido to version 0.2.1.
#
#   from .kaleido import Kaleido

# %%
runNRM(
    f="atan(x)",
    x0=1.45,
    know_root=None,
    tol=1e-6,
    max_iter=5,
    xLimit=None,
    yLimit=None,
    showTitle=True
)
# Out:
# Método de Newton-Raphson
# Função: -7*x**7 + 5*x**5 + x**3,
#  Derivada: -49*x**6 + 25*x**4 + 3*x**2,
#  Ponto Inicial (x0): 1
# ✓ Convergiu! Quantidade De Iterações: 5, Raiz: 0.9366
# Iteração 1: x = 1.00000000000000000, f(x) = -1.00000000000000000
# Iteração 2: x = 0.95238095238095233, f(x) = -0.19330088003707857
# Iteração 3: x = 0.93782067248258161, f(x) = -0.01418479118120164
# Iteração 4: x = 0.93657192815908463, f(x) = -0.00009731102705945
# Iteração 5: x = 0.93656324247741396, f(x) = -0.00000000468062922
# Iteração 6: x = 0.93656324205959529, f(x) = -0.00000000000000089
# {'root': 0.9365632420595953,
#  'iterations': [1,
#   0.9523809523809523,
#   0.9378206724825816,
#   0.9365719281590846,
#   0.936563242477414,
#   0.9365632420595953],
#  'converged': True,
#  'error_message': None,
#  'final_iteration': 5}
