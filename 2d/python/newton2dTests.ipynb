# %%
from newtonFractal import newton_fractal_plot
import numpy as np

# %%
n = 2
f = lambda z: z**n - 1
df = lambda z: n*z**(n-1)
roots = np.array([np.exp(2j * np.pi * k / n) for k in range(n)]) 
newton_fractal_plot(f=f, df = df,roots=roots, resolution=500, axiss=True, tol=1e-6)

# %%
n = 8
f = lambda z: z**n - 1
df = lambda z: n*z**(n-1)
roots = np.array([np.exp(2j * np.pi * k / n) for k in range(n)]) 
newton_fractal_plot(f=f, df = df,roots=roots, resolution=500, axiss=False, tol=1e-6 )
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.09999999999999998..0.8333333333333334].

# %%
n = 3
f = lambda z: z**n - 1
df = lambda z: n*z**(n-1)
roots = np.array([np.exp(2j * np.pi * k / n) for k in range(n)]) 
newton_fractal_plot(f=f, df = df,roots=roots, resolution=500, axiss=False, tol=1e-6 )
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.09999999999999998..0.8333333333333334].

# %%
n = 4
f = lambda z: z**n - 1
df = lambda z: n*z**(n-1)
roots = np.array([np.exp(2j * np.pi * k / n) for k in range(n)]) 
newton_fractal_plot(f=f, df = df,roots=roots, resolution=500, axiss=False, tol=1e-6 )
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.09999999999999998..0.8333333333333334].

# %%
n = 5
f = lambda z: z**n - 1
df = lambda z: n*z**(n-1)
roots = np.array([np.exp(2j * np.pi * k / n) for k in range(n)]) 
newton_fractal_plot(f=f, df = df,roots=roots, resolution=500, axiss=False, tol=1e-6 )
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.09999999999999998..0.8333333333333334].

# %%
n = 20
f = lambda z: z**n - 1
df = lambda z: n*z**(n-1)
roots = np.array([np.exp(2j * np.pi * k / n) for k in range(n)]) 
newton_fractal_plot(f=f, df = df,roots=roots, resolution=500, axiss=False, tol=1e-6 )
# Out:
# C:\Users\lumat\AppData\Local\Temp\ipykernel_772\2672625636.py:2: RuntimeWarning: overflow encountered in power
#   f = lambda z: z**n - 1
# C:\Users\lumat\AppData\Local\Temp\ipykernel_772\2672625636.py:2: RuntimeWarning: invalid value encountered in power
#   f = lambda z: z**n - 1
# C:\Users\lumat\AppData\Local\Temp\ipykernel_772\2672625636.py:3: RuntimeWarning: overflow encountered in power
#   df = lambda z: n*z**(n-1)
# C:\Users\lumat\AppData\Local\Temp\ipykernel_772\2672625636.py:3: RuntimeWarning: invalid value encountered in power
#   df = lambda z: n*z**(n-1)
# C:\Users\lumat\AppData\Local\Temp\ipykernel_772\2672625636.py:3: RuntimeWarning: overflow encountered in multiply
#   df = lambda z: n*z**(n-1)
# C:\Users\lumat\AppData\Local\Temp\ipykernel_772\2672625636.py:3: RuntimeWarning: invalid value encountered in multiply
#   df = lambda z: n*z**(n-1)
# c:\Users\lumat\OneDrive\Documentos\GitHub\Newton-Raphson\2d\python\newtonFractal.py:18: RuntimeWarning: overflow encountered in divide
#   Z = Z - f(Z) / df(Z)
# c:\Users\lumat\OneDrive\Documentos\GitHub\Newton-Raphson\2d\python\newtonFractal.py:18: RuntimeWarning: invalid value encountered in divide
#   Z = Z - f(Z) / df(Z)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.09999999999999998..0.8333333333333334].

# %%
f = lambda z: 3*z**5 + z**4 - z**2 + z - 1
df = lambda z: 15*z**4 + 4*z**3 - 2*z + 1
coefs = [3,1, 0, -1, 1, -1] 
roots = np.roots(coefs)
newton_fractal_plot(f=f, df = df,roots=roots, resolution=500, axiss=False)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.09999999999999998..0.8333333333333334].

# %%
f = lambda z: z**5 + z**2 - z + 1
df = lambda z: 5*z**4 + 2*z - 1
coefs = [1, 0, 0, 1, -1, 1]
roots = np.roots(coefs)
newton_fractal_plot(f=f, df=df, roots=roots, resolution=500, axiss=False)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.09999999999999998..0.8333333333333334].

# %%
f = lambda z: (z-2) * (2*z+3) * (3*z+2)
df = lambda z: 2 * (-10 + z + 9*z **2)
roots = [2,-3/2, -2/3]
newton_fractal_plot(f=f, df=df, roots=roots, resolution=500, axiss=False)
